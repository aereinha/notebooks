# %%
import numpy as np
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
#import pygrib
import matplotlib as mt
import ttuatmo.radar.ctables as ct
import glob
import netCDF4 as nc
import datetime

# %%
p0 = np.zeros(361)
p=np.zeros(361)
p1=np.zeros(361)
p6=np.zeros(181)
p9 = np.zeros(181)
p12 = np.zeros(181)
p15 = np.zeros(181)
p18 = np.zeros(181)
p21 = np.zeros(181)
pall1=0.

a=nc.Dataset('/Users/aereinha/Documents/Dissertation/dfi517/psfc_stats.17dfi.nc',"r")
p0 = a.variables['sfc_pressure_tendency'][82::]
t0 = a.variables['forecast_time'][82::]
a.close()
a=nc.Dataset('/Users/aereinha/Documents/Dissertation/dfi517/psfc_stats.17nodfi.nc',"r")
p = a.variables['sfc_pressure_tendency'][:]
t = a.variables['forecast_time'][:]
a.close()
a=nc.Dataset('/Users/aereinha/Documents/Dissertation/dfi517/psfc_stats.pertnodfi.nc',"r")
p1 = a.variables['sfc_pressure_tendency'][:]
t1 = a.variables['forecast_time'][:]
a.close()
print(t0.shape)
pa = p*3600./100.*3.
pb = p0*3600./100.*3.
pc = p1*3600./100.*3.
plt.plot(t0,pa,'r',t,pb,'g',t1,pc,'y')
plt.savefig("noassimilation.png",dpi=300)
# Out:
# (361,)

# %%
p0 = np.zeros(361)
p=np.zeros(181)
p3=np.zeros(181)
p6=np.zeros(181)
p9 = np.zeros(181)
p12 = np.zeros(181)
p15 = np.zeros(181)
p18 = np.zeros(181)
p21 = np.zeros(181)
#for i in glob.glob('/Users/aereinha/Documents/Dissertation/dumasmeso/outputdfi/2010051718/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p0 = p0 + a.variables['sfc_pressure_tendency'][82::]
#    t0 = a.variables['forecast_time'][82::]-6.
#    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputdfi3hr/2010051718/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p0 = p0 + a.variables['sfc_pressure_tendency'][:]
#    t0 = a.variables['forecast_time'][:]-6.
#    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputdfi3hr/2010051800/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p = p + a.variables['sfc_pressure_tendency'][82::]
    t = a.variables['forecast_time'][82::]
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputdfi3hr/2010051803/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p3 = p3 + a.variables['sfc_pressure_tendency'][82::]
    t3 = a.variables['forecast_time'][82::]+3.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputdfi3hr/2010051806/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p6 = p6 + a.variables['sfc_pressure_tendency'][82::]
    t6 = a.variables['forecast_time'][82::]+6.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputdfi3hr/2010051809/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p9 = p9 + a.variables['sfc_pressure_tendency'][82::]
    t9 = a.variables['forecast_time'][82::]+9.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputdfi3hr/2010051812/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p12 = p12 + a.variables['sfc_pressure_tendency'][82::]
    t12 = a.variables['forecast_time'][82::]+12.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputdfi3hr/2010051815/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p15 = p15 + a.variables['sfc_pressure_tendency'][82::]
    t15 = a.variables['forecast_time'][82::]+15.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputdfi3hr/2010051818/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p18 = p18 + a.variables['sfc_pressure_tendency'][82::]
    t18 = a.variables['forecast_time'][82::]+18.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputdfi3hr/2010051821/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p21 = p21 + a.variables['sfc_pressure_tendency'][82::]
    t21 = a.variables['forecast_time'][82::]+21.
    a.close()
p0 = p0/50.
p = p/50.
p3=p3/50.
p6=p6/50.
p9=p9/50.
p12=p12/50.
p15=p15/50.
p18=p18/50.
p21=p21/50.

# %%
pa0 = np.zeros(361)
pa1=np.zeros(181)
pa3=np.zeros(181)
pa6=np.zeros(181)
pa9 = np.zeros(181)
pa12 = np.zeros(181)
pa15 = np.zeros(181)
pa18 = np.zeros(181)
pa21 = np.zeros(181)

#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi3hr/2010051718/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    pa0 = pa0 + a.variables['sfc_pressure_tendency'][:]
#    ta0 = a.variables['forecast_time'][:]-6.
#    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi3hr/2010051800/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa1 = pa1 + a.variables['sfc_pressure_tendency'][:]
    ta1 = a.variables['forecast_time'][:]
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi3hr/2010051803/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa3 = pa3 + a.variables['sfc_pressure_tendency'][:]
    ta3 = a.variables['forecast_time'][:]+3.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi3hr/2010051806/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa6 = pa6 + a.variables['sfc_pressure_tendency'][:]
    ta6 = a.variables['forecast_time'][:]+6.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi3hr/2010051809/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa9 = pa9 + a.variables['sfc_pressure_tendency'][:]
    ta9 = a.variables['forecast_time'][:]+9.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi3hr/2010051812/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa12 = pa12 + a.variables['sfc_pressure_tendency'][:]
    ta12 = a.variables['forecast_time'][:]+12.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi3hr/2010051815/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa15 = pa15 + a.variables['sfc_pressure_tendency'][:]
    ta15 = a.variables['forecast_time'][:]+15.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi3hr/2010051818/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa18 = pa18 + a.variables['sfc_pressure_tendency'][:]
    ta18 = a.variables['forecast_time'][:]+18.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi3hr/2010051821/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa21 = pa21 + a.variables['sfc_pressure_tendency'][:]
    ta21 = a.variables['forecast_time'][:]+21.
    a.close()
pa0 = pa0/50.
pa1 = pa1/50.
pa3=pa3/50.
pa6=pa6/50.
pa9=pa9/50.
pa12=pa12/50.
pa15=pa15/50.
pa18=pa18/50.
pa21=pa21/50.

# %%
#p0 = np.zeros(361)
pa=np.zeros(361)
pa1=np.zeros(361)
pa2=np.zeros(361)
pa3 = np.zeros(361)
ta = np.zeros(361)
ta1 = np.zeros(361)
ta2 = np.zeros(361)
ta3 = np.zeros(361)

#for i in glob.glob('/Users/aereinha/Documents/Dissertation/dumasmeso/outputdfi/2010051618/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p0 = p0 + a.variables['sfc_pressure_tendency'][82::]
#    t0 = a.variables['forecast_time'][82::]-6.
#    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso/outputnodfi/2010051700/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa = pa + a.variables['sfc_pressure_tendency'][:]
    ta = a.variables['forecast_time'][:]
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso/outputnodfi/2010051706/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa1 = pa1 + a.variables['sfc_pressure_tendency'][:]
    ta1 = a.variables['forecast_time'][:]+6.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso/outputnodfi/2010051712/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa2 = pa2 + a.variables['sfc_pressure_tendency'][:]
    ta2 = a.variables['forecast_time'][:]+12.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso/outputnodfi/2010051718/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa3 = pa3 + a.variables['sfc_pressure_tendency'][:]
    ta3 = a.variables['forecast_time'][:]+18.
    a.close()
#p0 = p0/50.
pa = pa/50.
pa1=pa1/50.
pa2=pa2/50.
pa3=pa3/50.

# %%
#p0 = np.zeros(361)
pb=np.zeros(361)
pb1=np.zeros(361)
pb2=np.zeros(361)
pb3 = np.zeros(361)
t = np.zeros(361)
t1=np.zeros(361)
t2=np.zeros(361)
t3=np.zeros(361)
#for i in glob.glob('/Users/aereinha/Documents/Dissertation/dumasmeso/outputdfi/2010051618/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p0 = p0 + a.variables['sfc_pressure_tendency'][82::]
#    t0 = a.variables['forecast_time'][82::]-6.
#    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso/outputdfi/2010051700/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pb = pb + a.variables['sfc_pressure_tendency'][82::]
    t = a.variables['forecast_time'][82::]
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso/outputdfi/2010051706/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pb1 = pb1 + a.variables['sfc_pressure_tendency'][82::]
    t1 = a.variables['forecast_time'][82::]+6.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso/outputdfi/2010051712/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pb2 = pb2 + a.variables['sfc_pressure_tendency'][82::]
    t2 = a.variables['forecast_time'][82::]+12.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_*.nc'):
    print i
    a=nc.Dataset(i,"r")
    pb3 = pb3 + a.variables['sfc_pressure_tendency'][82::]
    t3 = a.variables['forecast_time'][82::]+18.
    a.close()
#p0 = p0/50.
p = pb/50.
p1=pb1/50.
p2=pb2/50.
p3=pb3/50.
# Out:
# /Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_1.nc
# /Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_10.nc
# /Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_11.nc
# /Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_12.nc
# /Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_13.nc
# /Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_14.nc
# /Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_15.nc
# /Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_16.nc
# /Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_17.nc
# /Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_18.nc
# /Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_19.nc
# ...

# %%
p0=np.zeros(361)
p1=np.zeros(361)
for i in glob.glob('/Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p0 = p0 + a.variables['sfc_pressure_tendency'][82::]
    t0 = a.variables['forecast_"time'][82::]+18.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi3hr/2010051718/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p1 = p1 + a.variables['sfc_pressure_tendency'][:]
    t1 = a.variables['forecast_time'][:]+18.
    a.close()
p0=p0/50.
p1 = p1/50.
pb=p1*3600./100.*3.
pa=p0*3600./100.*3.
plt.plot(t0,pa,'-b',t1,pb,'--g')
plt.show()

# %%
#pall = np.hstack((p[1::],p3[1::],p6[1::],p9[1::],p12[1::],p15[1::],p18[1::],p21[1::]))
#pallno = np.hstack((pa1[1::],pa3[1::],pa6[1::],pa9[1::],pa12[1::],pa15[1::],pa18[1::],pa21[1::]))
#pall1 = pall*3600./100.*3.
#pallno1 = pallno*3600./100.*3.
#tall = np.hstack((t[1::],t3[1::],t6[1::],t9[1::],t12[1::],t15[1::],t18[1::],t21[1::]))
#tallno = np.hstack((ta1[1::],ta3[1::],ta6[1::],ta9[1::],ta12[1::],ta15[1::],ta18[1::],ta21[1::]))

pallno = np.hstack((p[1::],p1[1::],p2[1::],p3[1::]))
pall = np.hstack((pa[1::],pa1[1::],pa2[1::],pa3[1::]))
pall1 = pall*3600./100.*3.
pallno1 = pallno*3600./100.*3.
tall = np.hstack((t[1::],t1[1::],t2[1::],t3[1::]))
tallno = np.hstack((ta[1::],ta1[1::],ta2[1::],ta3[1::]))
print tallno.shape
print pallno1.shape
plots=plt.plot(tallno,pallno1,'g',tall,pall1,'b',linewidth=2)

#plots=plt.plot(tall,pall1,linewidth=2)
plots=plt.xlabel('Hours since 17 June 2010 00 UTC')
plots=plt.ylabel(r' Surface Pressure Tendency (hPa 3hr$^{-1}$)')
plt.legend(('DFI', 'No-DFI') )


plt.axis([0, 24, 0, 25])
plt.savefig('dpsdtDFIvsNoDFI6Hr1.png',dpi=300)
#plt.show()
# Out:
# (1440,)
# (1440,)

# %%
e

# %%
# %pylab osx
# %config InlineBackend.figure_format = 'svg'
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: MacOSX].
# For more information, type 'help(pylab)'.

# %%
glob.glob('/Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_*.nc')
# Out:
# ['/Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_1.nc',
#  '/Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_10.nc',
#  '/Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_11.nc',
#  '/Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_12.nc',
#  '/Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_13.nc',
#  '/Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_14.nc',
#  '/Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_15.nc',
#  '/Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_16.nc',
#  '/Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_17.nc',
#  '/Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_18.nc',
#  '/Volumes/External/aereinha/dumasmeso/outputdfi/2010051718/psfc/psfc_stat_d01_19.nc',
# ...

# %%
p=np.zeros(61)
p1=np.zeros(61)
p2=np.zeros(61)
p3=np.zeros(61)
p4=np.zeros(61)
p5=np.zeros(61)
p6=np.zeros(61)
p7=np.zeros(61)
p8=np.zeros(61)
p9=np.zeros(61)
p10=np.zeros(61)
p11=np.zeros(61)
p12=np.zeros(61)
p13 = np.zeros(61)
p14 = np.zeros(61)
p15 = np.zeros(61)
p16 = np.zeros(61)
p17 = np.zeros(61)
p18 = np.zeros(61)
p19 = np.zeros(61)
p20 = np.zeros(61)
p21 = np.zeros(61)
p22 = np.zeros(61)
p23 = np.zeros(61)
p24 = np.zeros(61)

#for i in glob.glob('/Users/aereinha/Documents/Dissertation/dumasmeso/outputdfi/2010051718/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p0 = p0 + a.variables['sfc_pressure_tendency'][82::]
#    t0 = a.variables['forecast_time'][82::]-6.
#    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputdfi3hr/2010051718/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p0 = p0 + a.variables['sfc_pressure_tendency'][:]
#    t0 = a.variables['forecast_time'][:]-6.
#    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051800/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p = p + a.variables['sfc_pressure_tendency'][82::]
    t = a.variables['forecast_time'][82::]
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051801/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p1 = p1 + a.variables['sfc_pressure_tendency'][82::]
    t1 = a.variables['forecast_time'][82::]+1.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051802/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p2 = p2 + a.variables['sfc_pressure_tendency'][82::]
    t2 = a.variables['forecast_time'][82::]+2.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051803/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p3 = p3 + a.variables['sfc_pressure_tendency'][82::]
    t3 = a.variables['forecast_time'][82::]+3.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051804/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p4 = p4 + a.variables['sfc_pressure_tendency'][82::]
    t4 = a.variables['forecast_time'][82::]+4.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051805/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p5 = p5 + a.variables['sfc_pressure_tendency'][82::]
    t5 = a.variables['forecast_time'][82::]+5.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051806/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p6 = p6 + a.variables['sfc_pressure_tendency'][82::]
    t6 = a.variables['forecast_time'][82::]+6.
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051807/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p7 = p7 + a.variables['sfc_pressure_tendency'][82::]
    t7 = a.variables['forecast_time'][82::]+7
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051808/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p8 = p8 + a.variables['sfc_pressure_tendency'][82::]
    t8 = a.variables['forecast_time'][82::]+8
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051809/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p9 = p9 + a.variables['sfc_pressure_tendency'][82::]
    t9 = a.variables['forecast_time'][82::]+9
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051810/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p10 = p10 + a.variables['sfc_pressure_tendency'][82::]
    t10 = a.variables['forecast_time'][82::]+10
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051811/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p11 = p11 + a.variables['sfc_pressure_tendency'][82::]
    t11 = a.variables['forecast_time'][82::]+11
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051812/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p12 = p12 + a.variables['sfc_pressure_tendency'][82::]
    t12 = a.variables['forecast_time'][82::]+12
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051813/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p13 = p13 + a.variables['sfc_pressure_tendency'][82::]
    t13 = a.variables['forecast_time'][82::]+13
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051814/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p14 = p14 + a.variables['sfc_pressure_tendency'][82::]
    t14 = a.variables['forecast_time'][82::]+14
    a.close()
for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051815/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    p15 = p15 + a.variables['sfc_pressure_tendency'][82::]
    t15 = a.variables['forecast_time'][82::]+15
    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051816/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p16 = p16 + a.variables['sfc_pressure_tendency'][82::]
#    t16 = a.variables['forecast_time'][82::]+16
#    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051817/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p17 = p17 + a.variables['sfc_pressure_tendency'][82::]
#    t17 = a.variables['forecast_time'][82::]+17
#    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051818/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p18 = p18 + a.variables['sfc_pressure_tendency'][82::]
#    t18 = a.variables['forecast_time'][82::]+18
#    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051819/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p19 = p19 + a.variables['sfc_pressure_tendency'][82::]
#    t19 = a.variables['forecast_time'][82::]+19
#    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051820/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p20 = p20 + a.variables['sfc_pressure_tendency'][82::]
#    t20 = a.variables['forecast_time'][82::]+20
#    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051821/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p21 = p21 + a.variables['sfc_pressure_tendency'][82::]
#    t21 = a.variables['forecast_time'][82::]+21
#    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051822/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p22 = p22 + a.variables['sfc_pressure_tendency'][82::]
#    t22 = a.variables['forecast_time'][82::]+22
#    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051823/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p23 = p23 + a.variables['sfc_pressure_tendency'][82::]
#    t23 = a.variables['forecast_time'][82::]+23
#    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051824/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p24 = p24 + a.variables['sfc_pressure_tendency'][82::]
#    t24 = a.variables['forecast_time'][82::]+24
#    a.close()
p = p/50.
p1=p1/50.
p2=p2/50.
p3=p3/50.
p4=p4/50.
p5=p5/50.
p6=p6/50.
p7=p7/50.
p8 = p8/50.
p9=p9/50.
p10=p10/50.
p11=p11/50.
p12=p12/50.
p13=p13/50.
p14=p14/50.
p15=p15/50.
p16 = p16/50.
p17=p17/50.
p18=p18/50.
p19=p19/50.
p20=p20/50.
p20=p21/50.
p22=p22/50.
p23=p23/50.
p24 = p24/50.

# %%
pa=np.zeros(61)
pa1=np.zeros(61)
pa2=np.zeros(61)
pa3=np.zeros(61)
pa4=np.zeros(61)
pa5=np.zeros(61)
pa6=np.zeros(61)
pa7=np.zeros(61)
pa8=np.zeros(61)
pa9=np.zeros(61)
pa10=np.zeros(61)
pa11=np.zeros(61)
pa12=np.zeros(61)
pa13 = np.zeros(61)
pa14 = np.zeros(61)
pa15 = np.zeros(61)
pa16 = np.zeros(61)
pa17 = np.zeros(61)
pa18 = np.zeros(61)
pa19 = np.zeros(61)
pa20 = np.zeros(61)
pa21 = np.zeros(61)
pa22 = np.zeros(61)
pa23 = np.zeros(61)
pa24 = np.zeros(61)

#for i in glob.glob('/Users/aereinha/Documents/Dissertation/dumasmeso/outputdfi/2010051718/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p0 = p0 + a.variables['sfc_pressure_tendency'][82::]
#    t0 = a.variables['forecast_time'][82::]-6.
#    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputdfi3hr/2010051718/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p0 = p0 + a.variables['sfc_pressure_tendency'][:]
#    t0 = a.variables['forecast_time'][:]-6.
#    a.close()
for i in glob.glob('/Volumes/Stor/nodfi1hr/2010051800/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa = pa + a.variables['sfc_pressure_tendency'][:]
    t = a.variables['forecast_time'][:]
    a.close()
for i in glob.glob('/Volumes/Stor/nodfi1hr/2010051801/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa1 = pa1 + a.variables['sfc_pressure_tendency'][:]
    t1 = a.variables['forecast_time'][:]+1.
    a.close()
for i in glob.glob('/Volumes/Stor/nodfi1hr/2010051802/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa2 = pa2 + a.variables['sfc_pressure_tendency'][:]
    t2 = a.variables['forecast_time'][:]+2.
    a.close()
for i in glob.glob('/Volumes/Stor/nodfi1hr/2010051803/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa3 = pa3 + a.variables['sfc_pressure_tendency'][:]
    t3 = a.variables['forecast_time'][:]+3.
    a.close()
for i in glob.glob('/Volumes/Stor/nodfi1hr/2010051804/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa4 = pa4 + a.variables['sfc_pressure_tendency'][:]
    t4 = a.variables['forecast_time'][:]+4.
    a.close()
for i in glob.glob('/Volumes/Stor/nodfi1hr/2010051805/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa5 = pa5 + a.variables['sfc_pressure_tendency'][:]
    t5 = a.variables['forecast_time'][:]+5.
    a.close()
for i in glob.glob('/Volumes/Stor/nodfi1hr/2010051806/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa6 = pa6 + a.variables['sfc_pressure_tendency'][:]
    t6 = a.variables['forecast_time'][:]+6.
    a.close()
for i in glob.glob('/Volumes/Stor/nodfi1hr/2010051807/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa7 = pa7 + a.variables['sfc_pressure_tendency'][:]
    t7 = a.variables['forecast_time'][:]+7
    a.close()
for i in glob.glob('/Volumes/Stor/nodfi1hr/2010051808/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa8 = pa8 + a.variables['sfc_pressure_tendency'][:]
    t8 = a.variables['forecast_time'][:]+8
    a.close()
for i in glob.glob('/Volumes/Stor/nodfi1hr/2010051809/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa9 = pa9 + a.variables['sfc_pressure_tendency'][:]
    t9 = a.variables['forecast_time'][:]+9
    a.close()
for i in glob.glob('/Volumes/Stor/nodfi1hr/2010051810/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa10 = pa10 + a.variables['sfc_pressure_tendency'][:]
    t10 = a.variables['forecast_time'][:]+10
    a.close()
for i in glob.glob('/Volumes/Stor/nodfi1hr/2010051811/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa11 = pa11 + a.variables['sfc_pressure_tendency'][:]
    t11 = a.variables['forecast_time'][:]+11
    a.close()
for i in glob.glob('/Volumes/Stor/nodfi1hr/2010051812/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa12 = pa12 + a.variables['sfc_pressure_tendency'][:]
    t12 = a.variables['forecast_time'][:]+12
    a.close()
for i in glob.glob('/Volumes/Stor/nodfi1hr/2010051813/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa13 = pa13 + a.variables['sfc_pressure_tendency'][:]
    t13 = a.variables['forecast_time'][:]+13
    a.close()
for i in glob.glob('/Volumes/Stor/nodfi1hr/2010051814/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa14 = pa14 + a.variables['sfc_pressure_tendency'][:]
    t14 = a.variables['forecast_time'][:]+14
    a.close()
for i in glob.glob('/Volumes/Stor/nodfi1hr/2010051815/psfc/psfc_*.nc'):
    a=nc.Dataset(i,"r")
    pa15 = pa15 + a.variables['sfc_pressure_tendency'][:]
    t15 = a.variables['forecast_time'][:]+15
    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051816/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p16 = p16 + a.variables['sfc_pressure_tendency'][82::]
#    t16 = a.variables['forecast_time'][82::]+16
#    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051817/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p17 = p17 + a.variables['sfc_pressure_tendency'][82::]
#    t17 = a.variables['forecast_time'][82::]+17
#    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051818/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p18 = p18 + a.variables['sfc_pressure_tendency'][82::]
#    t18 = a.variables['forecast_time'][82::]+18
#    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051819/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p19 = p19 + a.variables['sfc_pressure_tendency'][82::]
#    t19 = a.variables['forecast_time'][82::]+19
#    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051820/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p20 = p20 + a.variables['sfc_pressure_tendency'][82::]
#    t20 = a.variables['forecast_time'][82::]+20
#    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051821/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p21 = p21 + a.variables['sfc_pressure_tendency'][82::]
#    t21 = a.variables['forecast_time'][82::]+21
#    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051822/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p22 = p22 + a.variables['sfc_pressure_tendency'][82::]
#    t22 = a.variables['forecast_time'][82::]+22
#    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051823/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p23 = p23 + a.variables['sfc_pressure_tendency'][82::]
#    t23 = a.variables['forecast_time'][82::]+23
#    a.close()
#for i in glob.glob('/Volumes/External/aereinha/dumasmeso1/outputnodfi1hr/2010051824/psfc/psfc_*.nc'):
#    a=nc.Dataset(i,"r")
#    p24 = p24 + a.variables['sfc_pressure_tendency'][82::]
#    t24 = a.variables['forecast_time'][82::]+24
#    a.close()
pa = pa/50.
pa1=pa1/50.
pa2=pa2/50.
pa3=pa3/50.
pa4=pa4/50.
pa5=pa5/50.
pa6=pa6/50.
pa7=pa7/50.
pa8 = pa8/50.
pa9=pa9/50.
pa10=pa10/50.
pa11=pa11/50.
pa12=pa12/50.
pa13=pa13/50.
pa14=pa14/50.
pa15=pa15/50.
pa16 = pa16/50.
pa17=pa17/50.
pa18=pa18/50.
pa19=pa19/50.
pa20=pa20/50.
pa20=pa21/50.
pa22=pa22/50.
pa23=pa23/50.
pa24 = pa24/50.

# %%
pallno = np.hstack((pa[1::],pa1[1::],pa2[1::],pa3[1::],pa4[1::],pa5[1::],pa6[1::],pa7[1::],pa8[1::],pa9[1::],pa10[1::],pa11[1::],pa12[1::],pa13[1::],pa14[1::],pa15[1::]))
pall = np.hstack((p[1::],p1[1::],p2[1::],p3[1::],p4[1::],p5[1::],p6[1::],p7[1::],p8[1::],p9[1::],p10[1::],p11[1::],p12[1::],p13[1::],p14[1::],p15[1::]))
pall1 = pall*3600./100.*3.
pallno1 = pallno*3600./100.*3.
tall = np.hstack((t[1::],t1[1::],t2[1::],t3[1::],t4[1::],t5[1::],t6[1::],t7[1::],t8[1::],t9[1::],t10[1::],t11[1::],t12[1::],t13[1::],t14[1::],t15[1::]))
#tallno = np.hstack((ta[1::],ta1[1::],ta2[1::],ta3[1::]))
#print tallno.shape
#print pallno1.shape
plots=plt.plot(tall,pall1,'b',tall,pallno1,'r',linewidth=2)

#plots=plt.plot(tall,pall1,linewidth=2)
plots=plt.xlabel('Hours since 17 June 2010 00 UTC')
plots=plt.ylabel(r' Surface Pressure Tendency (hPa 3hr$^{-1}$)')
plt.legend(('DFI', 'No-DFI') )
